# %% [markdown]
# ## Datasets

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, accuracy_score, confusion_matrix

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("../data/synthetic_transaction_data_Dining_sample.csv")
df.head()
# Out:
#        transaction_id     transaction_date    cardholder_name  \
# 0  RWYHDO-3GGJ-C6O515  2020-01-26 19:42:00     Michael Reeves
# 1  Z89V2U-I424-IFSZV7  2019-04-02 08:43:00    Ronnie Campbell
# 2  K0TE6E-DOI6-QFYN7V  2021-02-08 07:15:00    Stephanie Jones
# 3  CSUA5F-W9JY-7I76NR  2020-03-25 20:23:00     Julie Thompson
# 4  LF78UN-TIDZ-0MEJT8  2019-05-21 15:12:00  Jennifer Guerrero
#
#         card_number   card_type             merchant_name merchant_category  \
# 0  2294962353648068  mastercard           Texas Roadhouse     Casual Dining
# 1  2405289794587515  mastercard                Applebee's     Casual Dining
# 2   377983560222319        amex                   Wendy's         Fast Food
# 3  5146762679142298  mastercard  Carrabba's Italian Grill     Casual Dining
# 4  6533450566540076    discover                 Red Robin     Casual Dining
#
#   merchant_state  merchant_city transaction_status  transaction_amount  \
# 0       Michigan   Grand Rapids         Successful            0.355950
# 1         Kansas  Overland Park            Pending           15.206107
# 2          Maine       Portland            Pending           13.244500
# 3  New Hampshire     Manchester         Successful          214.316148
# 4       Kentucky      Lexington         Successful           10.536344
#
#   merchant_category_code  fraud_flag
# 0               MCC 5812           0
# 1               MCC 5812           0
# 2               MCC 5814           0
# 3               MCC 5812           1
# 4               MCC 5812           0
